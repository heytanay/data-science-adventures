# %%
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
df = pd.read_csv('./renfe.csv')

# %%
df.head()
# Out:
#    Unnamed: 0          insert_date  origin destination           start_date  \
# 0           0  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 06:20:00
# 1           1  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:00:00
# 2           2  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 07:30:00
# 3           3  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:00:00
# 4           4  2019-04-19 05:31:43  MADRID     SEVILLA  2019-05-29 08:30:00
#
#               end_date train_type  price train_class   fare
# 0  2019-05-29 09:16:00    AV City  38.55     Turista  Promo
# 1  2019-05-29 09:32:00        AVE  53.40     Turista  Promo
# 2  2019-05-29 09:51:00        AVE  47.30     Turista  Promo
# 3  2019-05-29 10:32:00        AVE  69.40  Preferente  Promo
# 4  2019-05-29 11:14:00      ALVIA    NaN     Turista  Promo

# %% [markdown]
# # Let's Drop all the Unwanted Columns first

# %% [markdown]
# ### The Columns "insert_date" and "Unnamed: 0" are not useful as:
# #### 1. We don't need to "insert_date" to be analysed as it was feed in when the specific Data was inserted by the Scraper
# #### 2. We also don't need "Unnamed: 0" as it is a false index column

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.drop(['insert_date'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    origin destination           start_date             end_date train_type  \
# 0  MADRID     SEVILLA  2019-05-29 06:20:00  2019-05-29 09:16:00    AV City
# 1  MADRID     SEVILLA  2019-05-29 07:00:00  2019-05-29 09:32:00        AVE
# 2  MADRID     SEVILLA  2019-05-29 07:30:00  2019-05-29 09:51:00        AVE
# 3  MADRID     SEVILLA  2019-05-29 08:00:00  2019-05-29 10:32:00        AVE
# 4  MADRID     SEVILLA  2019-05-29 08:30:00  2019-05-29 11:14:00      ALVIA
#
#    price train_class   fare
# 0  38.55     Turista  Promo
# 1  53.40     Turista  Promo
# 2  47.30     Turista  Promo
# 3  69.40  Preferente  Promo
# 4    NaN     Turista  Promo

# %% [markdown]
# ### Now let's deal with NaN (Not a Number) values in the Dataframe
# #### First, let's check the number of NaN values in the Dataset

# %%
df.isna().sum()
# Out:
# origin              0
# destination         0
# start_date          0
# end_date            0
# train_type          0
# price          310681
# train_class      9664
# fare             9664
# dtype: int64

# %% [markdown]
# #### As seen from above output, there are a total of 310,681 NaN values in "price" column and 9664 NaN values in both "train_class" and "fare" columns.
# #### We now have 2 choices: Either to drop the rows having any NaN value or to replace NaN values by mean of the whole column
# #### We will do both of them:
# Let's do the mean method and then drop the values which are hard to take mean of.

# %%
# First we make a Copy of the Dataframe and proceed on it, so don't have to reimport the Dataset, should we mess up.
df_copy = df.copy(deep=True)
df.head()
# Out:
#    origin destination           start_date             end_date train_type  \
# 0  MADRID     SEVILLA  2019-05-29 06:20:00  2019-05-29 09:16:00    AV City
# 1  MADRID     SEVILLA  2019-05-29 07:00:00  2019-05-29 09:32:00        AVE
# 2  MADRID     SEVILLA  2019-05-29 07:30:00  2019-05-29 09:51:00        AVE
# 3  MADRID     SEVILLA  2019-05-29 08:00:00  2019-05-29 10:32:00        AVE
# 4  MADRID     SEVILLA  2019-05-29 08:30:00  2019-05-29 11:14:00      ALVIA
#
#    price train_class   fare
# 0  38.55     Turista  Promo
# 1  53.40     Turista  Promo
# 2  47.30     Turista  Promo
# 3  69.40  Preferente  Promo
# 4    NaN     Turista  Promo

# %%
# Now let's do this column wise
df_copy.price = df_copy.price.fillna((df.price.mean()))
df_copy.head()
# As you can see there don't seem be any NaN values in "price" column
# Out:
#    origin destination           start_date             end_date train_type  \
# 0  MADRID     SEVILLA  2019-05-29 06:20:00  2019-05-29 09:16:00    AV City
# 1  MADRID     SEVILLA  2019-05-29 07:00:00  2019-05-29 09:32:00        AVE
# 2  MADRID     SEVILLA  2019-05-29 07:30:00  2019-05-29 09:51:00        AVE
# 3  MADRID     SEVILLA  2019-05-29 08:00:00  2019-05-29 10:32:00        AVE
# 4  MADRID     SEVILLA  2019-05-29 08:30:00  2019-05-29 11:14:00      ALVIA
#
#        price train_class   fare
# 0  38.550000     Turista  Promo
# 1  53.400000     Turista  Promo
# 2  47.300000     Turista  Promo
# 3  69.400000  Preferente  Promo
# 4  63.385503     Turista  Promo

# %% [markdown]
# 2. This was very convinient as the values in "price" column were Numerical. But the values in "train_class" and "fare" are categorical. So we are going to Drop them, now since there are only 9664 values; dropping them won't be that of a bummer!

# %%
df_copy.dropna(inplace=True)
# The option, 'inplace=True' will reassign it to the dataframe, so we don't have to do it manually

# Now let's find out all the NaN values in the dataset (hint hint: there aren't!)
df_copy.isna().sum()
# Out:
# origin         0
# destination    0
# start_date     0
# end_date       0
# train_type     0
# price          0
# train_class    0
# fare           0
# dtype: int64

# %% [markdown]
# As you can see, all the NaN values are dropped from the Dataset

# %% [markdown]
# ### Now let's Plot our Data one by one
#
# #### First, we shall plot the 'origins' column in a bar plot to see which city tops the list!

# %%
df_copy.origin.value_counts().plot(kind='bar')
plt.title("Train's Originating Frequency by Cities")
plt.xlabel("Cities")
plt.ylabel("Number of Trains")
plt.yscale('symlog')

fig = plt.gcf()
fig.set_size_inches(15.5, 5.5)

# %% [markdown]
# #### As you can see from above, Most number of trains originate from Madrid, Barcelona, Sevilla, Valencia and at the end Ponferrada
#
# #### Now let's Plot Train's Destination Frequency by Cities

# %%
df_copy.destination.value_counts().plot(kind='bar')
plt.title("Train's Destination Frequency by Cities")
plt.xlabel("Cities")
plt.ylabel("Number of Trains")
plt.yscale('symlog')

fig = plt.gcf()
fig.set_size_inches(15.5, 5.5)

# %% [markdown]
# #### The Above 2 Graphs indicate that Madrid is both the Destination and Origination spot for the majority of Trains.
# #### Infact, the Trains Arriving and Originating Distribution of the Trains are identical, which tell you a lot about the Data

# %% [markdown]
# ### Now let's Clean the Data a bit.
# #### We will first encode the categorical values

# %%
# First, let's get the different Destinations
df_copy.destination.value_counts()

# We will make the 'df.destination.value_counts()' as a dictionary object
dest_info = dict(df_copy.destination.value_counts())

# Now let's access all the keys (which are just the city names) using *.keys() function on the dictionary object we just created
city_names = list(dest_info.keys())
print(city_names)
# Out:
# ['BARCELONA', 'PONFERRADA', 'VALENCIA', 'MADRID', 'SEVILLA']

# %%
# Now let's replace origin and destination by making a simple function
def replace_small_categorical_data(df, column_name, categorical_names):
    copy_frame = df.copy(deep=True)
    
    copy_frame[column_name].replace(categorical_names, [x for x in range(len(categorical_names))], inplace=True)
    
    return copy_frame

# %%
# I have thus tested my custom function on the 'destination' column and they work just fine!

new_df_test = replace_small_categorical_data(df_copy, column_name='destination', categorical_names=city_names)
new_df_test.sample(10)
# Out:
#            origin  destination           start_date             end_date  \
# 153859     MADRID            2  2019-04-21 15:40:00  2019-04-21 17:22:00
# 384344    SEVILLA            3  2019-05-05 19:19:00  2019-05-05 21:59:00
# 262346  BARCELONA            3  2019-05-10 06:05:00  2019-05-10 09:15:00
# 540041     MADRID            4  2019-05-11 17:00:00  2019-05-11 19:38:00
# 901246     MADRID            0  2019-04-29 17:30:00  2019-04-29 20:40:00
# 983327     MADRID            0  2019-06-01 18:30:00  2019-06-01 21:20:00
# 72131     SEVILLA            3  2019-04-20 21:00:00  2019-04-20 23:52:00
# 568769   VALENCIA            3  2019-05-14 09:50:00  2019-05-14 17:28:00
# 245912    SEVILLA            3  2019-05-13 09:50:00  2019-05-13 12:36:00
# 969937     MADRID            4  2019-05-22 11:00:00  2019-05-22 13:32:00
#
#        train_type       price train_class        fare
# 153859        AVE   45.300000     Turista       Promo
# 384344  INTERCITY   63.385503     Turista    Flexible
# 262346        AVE   75.400000     Turista       Promo
# 540041        AVE   60.300000     Turista       Promo
# 901246        AVE  107.700000     Turista    Flexible
# 983327        AVE   75.400000     Turista       Promo
# 72131     AV City   62.200000     Turista    Flexible
# 568769   REGIONAL   28.350000     Turista  Adulto ida
# 245912      ALVIA   63.385503     Turista       Promo
# 969937        AVE   47.300000     Turista       Promo

# %% [markdown]
# #### As you can see above, the 'destination' column is converted into numerical column from a categorical one.
# #### Let's do the same for 'origin' column

# %%
# We will insert our new 'new_df_test' dataframe as it has the 'destination' column encoded
new_df_test = replace_small_categorical_data(new_df_test, column_name='origin', categorical_names=city_names)

# %%
# Let's look at the results;
new_df_test.head()
# Out:
#    origin  destination           start_date             end_date train_type  \
# 0       3            4  2019-05-29 06:20:00  2019-05-29 09:16:00    AV City
# 1       3            4  2019-05-29 07:00:00  2019-05-29 09:32:00        AVE
# 2       3            4  2019-05-29 07:30:00  2019-05-29 09:51:00        AVE
# 3       3            4  2019-05-29 08:00:00  2019-05-29 10:32:00        AVE
# 4       3            4  2019-05-29 08:30:00  2019-05-29 11:14:00      ALVIA
#
#        price train_class   fare
# 0  38.550000     Turista  Promo
# 1  53.400000     Turista  Promo
# 2  47.300000     Turista  Promo
# 3  69.400000  Preferente  Promo
# 4  63.385503     Turista  Promo

# %% [markdown]
# #### Now that out of the way, let's deal with remaining categorical columns, i.e: 'train_type', 'train_class' and 'fare'

# %%
# First, let's make a function to get all the different category names;
def get_category_names(df, column_name):
    '''
    Column passed must be categorical
    '''
    unique_names_dict = dict(df[column_name].value_counts())
    unique_names = list(unique_names_dict.keys())
    
    _length = len(unique_names)
    return (_length, unique_names)

# %% [markdown]
# ### Now we are ready to convert the 3 remaining columns into numerical but first let's look how there distribution looks like

# %%
new_df_test.train_type.value_counts().plot(kind='bar')
plt.title('Distribution of Train Types')
plt.xlabel('Train Types')
plt.ylabel('Number of trains')
plt.yscale('symlog')

fig = plt.gcf()
fig.set_size_inches(15.5, 5.5)

# %%
new_df_test.train_class.value_counts().plot(kind='bar')
plt.title('Distribution of Train Classes')
plt.xlabel('Train Classes')
plt.ylabel('Number of trains')
plt.yscale('symlog')

fig = plt.gcf()
fig.set_size_inches(15.5, 5.5)

# %%
new_df_test.fare.value_counts().plot(kind='bar')
plt.title('Distribution of Train Fare')
plt.xlabel('Train Fares')
plt.ylabel('Number of trains')
plt.yscale('symlog')

fig = plt.gcf()
fig.set_size_inches(15.5, 5.5)

# %% [markdown]
# #### Now you saw the distributions, let's encode those values!

# %% [markdown]
# #### First let's get the category names and encode them (this could be done in single loop easily but then it will be a little too complex to understand)

# %%
# First get category names
_, train_type_names = get_category_names(new_df_test, column_name='train_type')
_, train_class_names = get_category_names(new_df_test, column_name='train_class')
_, fare_names = get_category_names(new_df_test, column_name='fare')

# %%
# Now after this, let's encode these columns based on their category names
new_df_test = replace_small_categorical_data(new_df_test, column_name='train_type', categorical_names=train_type_names)
new_df_test = replace_small_categorical_data(new_df_test, column_name='train_class', categorical_names=6train_class_names)
new_df_test = replace_small_categorical_data(new_df_test, column_name='fare', categorical_names=fare_names)

# %%
new_df_test.sample(13)
# Out:
#          origin  destination           start_date             end_date  \
# 1253501       0            3  2019-05-10 20:00:00  2019-05-10 23:10:00
# 1092305       3            2  2019-05-10 15:10:00  2019-05-10 17:20:00
# 1221425       3            1  2019-05-08 17:30:00  2019-05-08 21:33:00
# 2234780       2            3  2019-05-29 17:10:00  2019-05-29 18:50:00
# 1297997       4            3  2019-05-29 20:36:00  2019-05-29 23:14:00
# 600442        3            4  2019-05-29 07:00:00  2019-05-29 09:32:00
# 793245        4            3  2019-05-10 10:45:00  2019-05-10 13:17:00
# 1008902       3            0  2019-05-07 07:30:00  2019-05-07 10:40:00
# 471096        2            3  2019-05-13 06:30:00  2019-05-13 08:22:00
# 202779        0            3  2019-04-28 10:00:00  2019-04-28 13:10:00
# 1429312       3            2  2019-05-09 12:21:00  2019-05-09 19:04:00
# 1508535       3            4  2019-06-15 09:00:00  2019-06-15 11:38:00
# 948962        3            2  2019-05-19 16:45:00  2019-05-19 18:50:00
#
#          train_type   price  train_class  fare
# 1253501          14   98.00            2     0
# 1092305          11   55.40            0     4
# 1221425           6   55.80            0     4
# 2234780          14   45.30            0     0
# 1297997           6   67.20            0     4
# 600442           14   53.40            0     0
# 793245           14   76.30            0     4
# 1008902          14   85.10            0     0
# 471096           14   39.45            0     0
# 202779           14  107.70            0     4
# 1429312          10   28.35            0     3
# 1508535          14   41.20            0     0
# 948962            6   71.00            0     4

# %% [markdown]
# ## We are almost done now! on the homestretch, let's actually deal with the elephant(s) in the room, i.e: 'start_date' and 'end_date' columns

# %%
# Let's get the duration of the trip in seconds and then we will get the weekdays
start_time = new_df_test['start_date'].values
end_time = new_df_test['end_date'].values

DATETIME = '%Y-%m-%d %H:%M:%S'

duration = list()

for i in range(len(start_time)):
    difference = datetime.datetime.strptime(end_time[i], DATETIME) - datetime.datetime.strptime(start_time[i], DATETIME)
    
    duration.append(difference.seconds)
    
new_df_test['duration'] = duration

# %%
new_df_test.head()
# Out:
#    origin  destination           start_date             end_date  train_type  \
# 0       3            4  2019-05-29 06:20:00  2019-05-29 09:16:00           9
# 1       3            4  2019-05-29 07:00:00  2019-05-29 09:32:00          14
# 2       3            4  2019-05-29 07:30:00  2019-05-29 09:51:00          14
# 3       3            4  2019-05-29 08:00:00  2019-05-29 10:32:00          14
# 4       3            4  2019-05-29 08:30:00  2019-05-29 11:14:00           6
#
#        price  train_class  fare  duration
# 0  38.550000            0     0     10560
# 1  53.400000            0     0      9120
# 2  47.300000            0     0      8460
# 3  69.400000            2     0      9120
# 4  63.385503            0     0      9840

# %%
# Let's now extract the weekdays using a similar way we used before
week_start = list()
week_end = list()

for i in start_time:
    week_start.append(datetime.datetime.strptime(i, DATETIME).weekday())

for i in end_time:
    week_end.append(datetime.datetime.strptime(i, DATETIME).weekday())
    
new_df_test['week_start'] = week_start
new_df_test['week_end'] = week_end

# %%
new_df_test.head()
# Out:
#    origin  destination           start_date             end_date  train_type  \
# 0       3            4  2019-05-29 06:20:00  2019-05-29 09:16:00           9
# 1       3            4  2019-05-29 07:00:00  2019-05-29 09:32:00          14
# 2       3            4  2019-05-29 07:30:00  2019-05-29 09:51:00          14
# 3       3            4  2019-05-29 08:00:00  2019-05-29 10:32:00          14
# 4       3            4  2019-05-29 08:30:00  2019-05-29 11:14:00           6
#
#        price  train_class  fare  duration  week_start  week_end
# 0  38.550000            0     0     10560           2         2
# 1  53.400000            0     0      9120           2         2
# 2  47.300000            0     0      8460           2         2
# 3  69.400000            2     0      9120           2         2
# 4  63.385503            0     0      9840           2         2
